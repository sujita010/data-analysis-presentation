# %% [markdown]
# # **Heart Disease EDA Analysis**

# %% [markdown]
# ## **Introduction**
# Heart disease remains one of the leading causes of death globally. Early detection and preventive measures can significantly improve patient outcomes and reduce healthcare costs. With the advancement of data science and machine learning, it has become increasingly possible to uncover hidden patterns in medical datasets that could help in predicting the likelihood of heart-related conditions.
#
# This project explores a publicly available heart disease dataset, analyzing various factors such as age, sex, cholesterol level, and maximum heart rate, among others. Through visualizations and statistical analysis, the study aims to understand the relationships between these attributes and the presence of heart disease.
#
# Dataset Feature:
#
# https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset/data
#
# ## **Objective**
# 1. The primary objectives of this project are:
#
# 2. To perform an exploratory data analysis (EDA) on the heart disease     dataset.
#
# 3. To understand the distribution of features such as age, sex, and maximum heart rate in relation to heart disease.
#
# 4. To visualize correlations among features and identify patterns that may contribute to heart disease prediction.
#
# 5. To lay the groundwork for future predictive modeling by analyzing key risk indicators.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv ("/content/heart.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-3398767615.py in <cell line: 0>()
# ----> 1 df = pd.read_csv ("/content/heart.csv")
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # **Data Info**

# %%
df['target']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
print(df[['age', 'target']].corr())
# Out:
#              age    target
# age     1.000000 -0.229324
# target -0.229324  1.000000

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %% [markdown]
# # **Box Plot: Age Distribution by Target**

# %%
# Crete Box Plot of Age

sns.boxplot(data=df, x="target", y="age")
plt.title('Age Distribution by Target')
plt.xlabel('Target')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# 1. Patients with heart disease (target = 1) tend to be slightly younger on average compared to those without heart disease.
#
# 2. There is a wider spread in the age of patients without heart disease, while those with heart disease are more concentrated in the mid-age range.

# %% [markdown]
# # **Bar Plot: Heart Disease Frequency by Sex**

# %%
pd.crosstab(df.sex,df.target).plot(kind="bar",figsize=(15,6),color=['red','green' ])
plt.title('Heart Disease Frequency for Sex')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.xticks(rotation=0)
plt.legend(["Haven't Disease", "Have Disease"])
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 1. Males (sex = 1) are more frequently represented in both categories, but especially among those with heart disease.
#
# 2. This suggests a higher prevalence or risk of heart disease in males compared to females in this dataset.

# %% [markdown]
# # **Scatter Plot: Age vs Max Heart Rate by Disease**

# %%
plt.scatter(x=df.age[df.target==1], y=df.thalach[(df.target==1)], c="red")
plt.scatter(x=df.age[df.target==0], y=df.thalach[(df.target==0)])
plt.legend(["Disease", "Not Disease"])
plt.xlabel("Age")
plt.ylabel("Maximum Heart Rate")
plt.show()

# %% [markdown]
# 1. Individuals with heart disease generally achieve lower maximum heart rates compared to those without heart disease.
#
# 2. Younger patients tend to have higher maximum heart rates overall, but the distinction between target classes becomes clearer as age increases.

# %% [markdown]
# # **Histogram: Age Distribution**

# %%
df['age'].hist(bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 1. Most patients fall between the ages of 40 to 60.
#
# 2. This reinforces the understanding that heart disease risk increases with age but is particularly concentrated in middle-aged individuals.

# %% [markdown]
# # **Heatmap: Correlation Matrix**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Between Attributes")
plt.show()

# %% [markdown]
# 1. thalach (maximum heart rate) is negatively correlated with heart disease (target).
#
# 2. cp (chest pain type) and sex show moderate positive correlations with heart disease.
#
# 3. Features like chol (cholesterol) and fbs (fasting blood sugar) show weaker correlations

# %% [markdown]
# # **Count Plot: Heart Disease by Gender**

# %%
sns.countplot(x='sex', hue='target', data=df)
plt.title('Heart Disease by Gender')
plt.xlabel('Sex (0 = Female, 1 = Male)')
plt.ylabel('Count')
plt.legend(title='Heart Disease')
plt.show()

# %% [markdown]
# 1. Again confirms that males are more affected by heart disease than females.
#
# 2. Among females, the proportion with heart disease appears lower.

# %% [markdown]
# # **Scatter Plot: Max Heart Rate vs Age (with Hue = Target)**

# %%
sns.scatterplot(x='age', y='thalach', hue='target', data=df)
plt.title('Max Heart Rate vs Age (by Heart Disease)')
plt.xlabel('Age')
plt.ylabel('Max Heart Rate')
plt.show()

# %% [markdown]
# 1. Shows a clear inverse trend: as age increases, maximum heart rate decreases.
#
# 2. The color separation (by target) again emphasizes that people with lower max heart rate tend to have heart disease.

# %% [markdown]
# # **Conclusion**
# The exploratory data analysis of the heart disease dataset provides meaningful insights into the factors associated with the presence of heart disease. Key findings include:
#
# **Age and Heart Disease**:
#
#  Middle-aged individuals (around 40–60 years) are the most affected. Younger individuals tend to have a lower risk, while older individuals show a wider range of risk depending on other health indicators.
#
# **Gender Differences:**
#
#  Males are more likely to suffer from heart disease compared to females in this dataset. This suggests that gender could be an important variable in risk assessment.
#
# **Heart Rate Patterns:**
#
#  A lower maximum heart rate (thalach) is often associated with the presence of heart disease, indicating it could be a potential early indicator.
#
# **Chest Pain Type and Correlation: **
#
# Certain types of chest pain (cp) show a strong positive correlation with heart disease, while features like cholesterol and fasting blood sugar show weaker relationships.
#
# **Feature Interactions:**
#
#  The correlation heatmap reveals that no single feature overwhelmingly predicts heart disease, reinforcing the importance of combining multiple indicators for accurate risk evaluation.
#
# Overall, the visual patterns and statistical relationships uncovered through EDA help lay a strong foundation for building predictive models. These insights can guide healthcare professionals in early detection efforts and support patients in managing their cardiovascular health through personalized interventions.
